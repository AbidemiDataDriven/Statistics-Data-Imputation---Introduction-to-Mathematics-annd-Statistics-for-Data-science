# %% [markdown]
# #import the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as st

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset("tips")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_data = sns.load_dataset("tips")
tips_data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_data.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
type(tips_data)
# Out:
# pandas.core.frame.DataFrame

# %%
tips_data.shape
# Out:
# (244, 7)

# %%
tips_data.size
# Out:
# 1708

# %% [markdown]
# ## DESCRIPTIVE **STATISTICS**

# %%
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_data.info()#concise summary of our dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips_data.describe()#descriptive statistics
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#distribution
sns.displot(data=tips_data, x="total_bill", bins=10, kde=False, color="r")

# %%
#Inllustrate Distribution data through the visualisation for the total bills
sns.displot(data=tips_data, x="total_bill", bins=10, kde=False, color = "b")

# %%
sns.displot(data=tips_data, x="tip", bins=10, kde=False, color="y")

# %%
tips_data.describe(include="all")#this usually describe all the features in the dataset via descriptive statistics
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %% [markdown]
# ## **MEDIAN**

# %%
#MEDIAN USE CASE
tips_data['tip'].mean()
# Out:
# 2.99827868852459

# %%
tips_data["tip"].median()
# Out:
# 2.9

# %%
sns.displot(data=tips_data, x="tip", bins=10, kde=False, color="orange"
           )

# %%
#tips_data = sns.FacetGrid(tips_data, col="time",  row="sex")
#tips_data.map(sns.scatterplot, "total_bill", "tip")

# %%
#create a list
list_median = [2, 3,4,5,6,7,2000]

# %%
np.median(list_median)
# Out:
# 5.0

# %%
tips_data_copy=tips_data.copy()

# %%
tips_data_copy["tip"][8] = np.nan
# Out:
# <ipython-input-57-76077961e169>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tips_data_copy["tip"][8] = np.nan

# %%
tips_data_copy["tip"].head(10)
# Out:
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# 5    4.71
# 6    2.00
# 7    3.12
# 8     NaN
# 9    3.23
# Name: tip, dtype: float64

# %%
tips_data_copy["tip"].fillna(tips_data_copy["tip"].median()).head(10)
# Out:
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# 5    4.71
# 6    2.00
# 7    3.12
# 8    2.92
# 9    3.23
# Name: tip, dtype: float64

# %%
tips_data_copy["tip"].fillna(tips_data_copy["tip"].mean()).head(10)
# Out:
# 0    1.010000
# 1    1.660000
# 2    3.500000
# 3    3.310000
# 4    3.610000
# 5    4.710000
# 6    2.000000
# 7    3.120000
# 8    3.002551
# 9    3.230000
# Name: tip, dtype: float64

# %%
tips_data_copy["tip"].describe()
# Out:
# count    243.000000
# mean       3.002551
# std        1.384880
# min        1.000000
# 25%        2.000000
# 50%        2.920000
# 75%        3.575000
# max       10.000000
# Name: tip, dtype: float64

# %% [markdown]
# ## **MEAN**

# %%
list_age = [23, 12, 24, 21, 23, 14, 28, 26, 24, 25]#age distribution

# %%
#average age distribution
np.mean(list_age)
# Out:
# 22.0

# %%
ist_age = [23, 12, 24, 21, 23, 14, 28, 26, 24, 25, 68]#updated age distribution

# %%
st.mean(list_age)
# Out:
# 22

# %%
tips_data["total_bill"].mean()
# Out:
# 19.78594262295082

# %%
sns.displot(data=tips_data, x="total_bill", bins=10, kde=False)

# %% [markdown]
# **MODE**

# %%
tips_data.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(data=tips_data, x="size", bins=10, kde=False, color="red")

# %%
tips_data["size"].mode()#find the specified mode as usual
# Out:
# 0    2
# Name: size, dtype: int64

# %% [markdown]
# **STANDARD** **DEVIATION**

# %%
list_std = [3, 2, 4, 5, 6]

# %%
np.mean(list_std)
# Out:
# 4.0

# %%
list_std1 = [3, 3, 2, 2, 3, 11]

# %%
np.mean(list_std1
       )
# Out:
# 4.0

# %%
#check their sd
np.std(list_std)
# Out:
# 1.4142135623730951

# %%
np.std(list_std1)
# Out:
# 3.1622776601683795

# %%
tips_data["total_bill"].mean()
# Out:
# 19.78594262295082

# %%
tips_data["total_bill"].std()
# Out:
# 8.902411954856856

# %%
tips_data["tip"].mean()
# Out:
# 2.99827868852459

# %%
tips_data["total_bill"].std()
# Out:
# 8.902411954856856

# %%
tips_data["tip"].mean()
# Out:
# 2.99827868852459

# %%
tips_data["tip"].std()
# Out:
# 1.3836381890011822

# %%
sns.displot(data=tips_data, x="total_bill", kde=False, color="green")

# %% [markdown]
# # INFERENTIAL **STATISTICS**

# %%
#look at the dataset
tips_data.head(5
              )
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_data.shape
# Out:
# (244, 7)

# %%
#take sample from the dataset using pandas dataframe method
tips_data_sample = tips_data.sample(frac=0.3, replace=True, random_state=1)

# %%
tips_data_sample
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 37        16.93  3.07  Female     No   Sat  Dinner     3
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 140       17.47  3.50  Female     No  Thur   Lunch     2
# 72        26.86  3.14  Female    Yes   Sat  Dinner     2
# 137       14.15  2.00  Female     No  Thur   Lunch     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 26        13.37  2.00    Male     No   Sat  Dinner     2
# 52        34.81  5.20  Female     No   Sun  Dinner     4
# 80        19.44  3.00    Male    Yes  Thur   Lunch     2
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2
# 115       17.31  3.50  Female     No   Sun  Dinner     2
#
# [73 rows x 7 columns]

# %%
tips_data_sample.shape
# Out:
# (73, 7)

# %%
tips_data_sample["total_bill"].mean()
# Out:
# 19.248630136986304

# %%
tips_data_sample["total_bill"].std()
# Out:
# 8.646551386257428

# %%
sns.scatterplot(data=tips_data_sample, x='total_bill', y="tip",hue = 'sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
